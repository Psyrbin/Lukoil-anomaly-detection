# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_hdf('Data.h5')

# %%
fft = np.fft.fft(data.iloc[:,i])

# %%
fft.shape
# Out:
# (43200,)

# %%
no_hf_fft = fft
for j in range (fft.shape[0] - 35000, fft.shape[0]):
    no_hf_fft[j] = 0

# %%
i = np.random.randint(data.shape[1])
plt.figure(figsize=(14,10))
plt.plot(data.index, data.iloc[:,i], color='red')
plt.plot(data.index, np.fft.ifft(no_hf_fft))
