# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_hdf('Data.h5')

# %%
data.head()
# Out:
#                      610FIC098 DACA.PV  610PIC002 PID_PLA.PV  \
# DATE AND TIME
# 2018-09-01 00:00:00        7499.013672              1.218441
# 2018-09-01 00:01:00        7551.958984              1.206157
# 2018-09-01 00:02:00        7466.616699              1.203238
# 2018-09-01 00:03:00        7535.733887              1.198222
# 2018-09-01 00:04:00        7462.890625              1.191046
#
#                      610PIC002 PID_PLA.SP  610PIC002 PID_PLA.OP  \
# DATE AND TIME
# 2018-09-01 00:00:00                   1.2             53.367477
# 2018-09-01 00:01:00                   1.2             53.573505
# 2018-09-01 00:02:00                   1.2             53.549259
# 2018-09-01 00:03:00                   1.2             53.253944
# 2018-09-01 00:04:00                   1.2             52.195477
#
#                      610TI001 DACA.PV  610TI002 DACA.PV  610TI004 DACA.PV  \
# DATE AND TIME
# 2018-09-01 00:00:00         27.346800        243.832260        240.098770
# 2018-09-01 00:01:00         27.356628        243.854996        240.131516
# 2018-09-01 00:02:00         27.215054        243.852661        240.328247
# 2018-09-01 00:03:00         27.281755        243.828598        240.317535
# 2018-09-01 00:04:00         27.286066        243.976868        240.375031
#
#                      610PDI124A DACA.PV  610PDI124B DACA.PV  610FI001 DACA.PV  \
# DATE AND TIME
# 2018-09-01 00:00:00            0.015847            0.007047       6743.284668
# 2018-09-01 00:01:00            0.015598            0.006995       6733.831543
# 2018-09-01 00:02:00            0.015659            0.006910       6752.866211
# 2018-09-01 00:03:00            0.015795            0.006793       6748.151367
# 2018-09-01 00:04:00            0.015478            0.006751       6740.555176
#
#                              ...           610PV041A SWITCHA.OP  \
# DATE AND TIME                ...
# 2018-09-01 00:00:00          ...                      76.363525
# 2018-09-01 00:01:00          ...                      76.046883
# 2018-09-01 00:02:00          ...                      76.111603
# 2018-09-01 00:03:00          ...                      76.250168
# 2018-09-01 00:04:00          ...                      76.180664
#
#                      610PV041B SWITCHA.OP  610FV048A AUTOMANA.OP  \
# DATE AND TIME
# 2018-09-01 00:00:00                  10.0              46.000000
# 2018-09-01 00:01:00                  10.0              46.000000
# 2018-09-01 00:02:00                  10.0              46.000000
# 2018-09-01 00:03:00                  10.0              46.000000
# 2018-09-01 00:04:00                  10.0              45.760117
#
#                      610FV048B AUTOMANA.OP  610FY047 OVRDSELA.OP  \
# DATE AND TIME
# 2018-09-01 00:00:00                    5.1                   0.0
# 2018-09-01 00:01:00                    5.1                   0.0
# 2018-09-01 00:02:00                    5.1                   0.0
# 2018-09-01 00:03:00                    5.1                   0.0
# 2018-09-01 00:04:00                    5.1                   0.0
#
#                      610TIC088 PID_PLA.PV.1  610TIC088 PID_PLA.OP.1  \
# DATE AND TIME
# 2018-09-01 00:00:00              423.010559               23.000000
# 2018-09-01 00:01:00              422.993652               23.000000
# 2018-09-01 00:02:00              422.985138               23.000000
# 2018-09-01 00:03:00              422.959717               23.000000
# 2018-09-01 00:04:00              422.963959               22.871855
#
#                      610TIC088 PID_PLA.SP.1  610TV182A SWITCHA.OP  \
# DATE AND TIME
# 2018-09-01 00:00:00              423.010559                  17.0
# 2018-09-01 00:01:00              422.993652                  17.0
# 2018-09-01 00:02:00              422.985138                  17.0
# 2018-09-01 00:03:00              422.959717                  17.0
# 2018-09-01 00:04:00              422.899994                  17.0
#
#                      610TV182B SWITCHA.OP
# DATE AND TIME
# 2018-09-01 00:00:00                  26.0
# 2018-09-01 00:01:00                  26.0
# 2018-09-01 00:02:00                  26.0
# 2018-09-01 00:03:00                  26.0
# 2018-09-01 00:04:00                  26.0
#
# [5 rows x 825 columns]

# %%
plt.figure(figsize=(20,10))
plt.bar(range(data.shape[1]), data.mean())
# Out:
# <BarContainer object of 825 artists>

# %%
means_without_largest = np.array(data.mean())
for _ in range(4):
    means_without_largest = np.delete(means_without_largest, np.argmax(means_without_largest))
plt.figure(figsize=(20,10))
plt.bar(range(len(means_without_largest)), means_without_largest)
# Out:
# <BarContainer object of 821 artists>

# %%
plt.figure(figsize=(20,10))
plt.bar(range(data.shape[1]), data.median())
# Out:
# <BarContainer object of 825 artists>

# %%
#Большая разница между медианой и средним говорит о наличии выбросов по краям распределения
plt.figure(figsize=(20,10))
plt.bar(range(data.shape[1]), data.mean() - data.median())
# Out:
# <BarContainer object of 825 artists>

# %%
plt.figure(figsize=(20,10))
plt.bar(range(data.shape[1]), data.std())
# Out:
# <BarContainer object of 825 artists>

# %%
#Как сильно максимум отклоняется от среднего плюс 2 стандартных отклонения
plt.figure(figsize=(20,10))
plt.bar(range(data.shape[1]), data.max() - data.mean() - 2*data.std())
# Out:
# <BarContainer object of 825 artists>

# %%
#Как сильно минимум отклоняется от среднего минус 2 стандартных отклонения
plt.figure(figsize=(20,10))
plt.bar(range(data.shape[1]), data.mean() - 2 * data.std() - data.min())
# Out:
# <BarContainer object of 825 artists>

# %%
# Нормализуем данные, чтобы посмотреть относительные значения статистик
normalized_data=(data-data.min())/(data.max()-data.min())

# %%
plt.figure(figsize=(20,10))
plt.bar(range(data.shape[1]), normalized_data.mean())
# Out:
# <BarContainer object of 825 artists>

# %%
plt.figure(figsize=(20,10))
plt.bar(range(data.shape[1]), normalized_data.mean() - normalized_data.median())
# Out:
# <BarContainer object of 825 artists>

# %%
plt.figure(figsize=(20,10))
plt.bar(range(data.shape[1]), normalized_data.std())
# Out:
# <BarContainer object of 825 artists>

# %%
plt.figure(figsize=(20,10))
plt.bar(range(data.shape[1]), normalized_data.max() - normalized_data.mean() - 2*normalized_data.std())
# Out:
# <BarContainer object of 825 artists>

# %%
plt.figure(figsize=(20,10))
plt.bar(range(data.shape[1]), normalized_data.mean() - 2*normalized_data.std() - normalized_data.min())
# Out:
# <BarContainer object of 825 artists>

# %%
SPs = pd.DataFrame()
for col_name, col_data in data.iteritems():
    if col_name[-2:] == 'SP':
        SPs.insert(0, col_name, col_data)

# %%
SPs.head()
# Out:
#                      610FIC074 PIDERA.SP  610PIC090 PIDERA.SP  \
# DATE AND TIME
# 2018-09-01 00:00:00          1085.331787                 0.25
# 2018-09-01 00:01:00          1086.068481                 0.25
# 2018-09-01 00:02:00          1086.620117                 0.25
# 2018-09-01 00:03:00          1087.415649                 0.25
# 2018-09-01 00:04:00          1087.998779                 0.25
#
#                      610TIC210 PID_PLA.SP  610PIC103 PID_PLA.SP  \
# DATE AND TIME
# 2018-09-01 00:00:00             83.166519                   8.3
# 2018-09-01 00:01:00             83.126572                   8.3
# 2018-09-01 00:02:00             83.128632                   8.3
# 2018-09-01 00:03:00             83.127144                   8.3
# 2018-09-01 00:04:00             83.076057                   8.3
#
#                      610FIC077 PID_PLA.SP  610TDIC206 PID_PLA.SP  \
# DATE AND TIME
# 2018-09-01 00:00:00               26000.0                    3.0
# 2018-09-01 00:01:00               26000.0                    3.0
# 2018-09-01 00:02:00               26000.0                    3.0
# 2018-09-01 00:03:00               26000.0                    3.0
# 2018-09-01 00:04:00               26000.0                    3.0
#
#                      610PIC154 PID_PLA.SP  610PIC085 PID_PLA.SP  \
# DATE AND TIME
# 2018-09-01 00:00:00             47.333790            198.227478
# 2018-09-01 00:01:00             47.291889            198.193695
# 2018-09-01 00:02:00             47.243374            198.226120
# 2018-09-01 00:03:00             47.232090            198.213684
# 2018-09-01 00:04:00             47.256191            198.219559
#
#                      610FIC071 PID_PLA.SP  610PIC084 PID_PLA.SP  \
# DATE AND TIME
# 2018-09-01 00:00:00               11000.0                   0.7
# 2018-09-01 00:01:00               11000.0                   0.7
# 2018-09-01 00:02:00               11000.0                   0.7
# 2018-09-01 00:03:00               11000.0                   0.7
# 2018-09-01 00:04:00               11000.0                   0.7
#
#                              ...           610PIC003 PID_PLA.SP  \
# DATE AND TIME                ...
# 2018-09-01 00:00:00          ...                            0.7
# 2018-09-01 00:01:00          ...                            0.7
# 2018-09-01 00:02:00          ...                            0.7
# 2018-09-01 00:03:00          ...                            0.7
# 2018-09-01 00:04:00          ...                            0.7
#
#                      610TIC012 PID_PLA.SP  610FIC095 PID_PLA.SP  \
# DATE AND TIME
# 2018-09-01 00:00:00            175.040726         158064.140625
# 2018-09-01 00:01:00            174.494202         158064.140625
# 2018-09-01 00:02:00            174.780792         158064.140625
# 2018-09-01 00:03:00            174.440292         158064.140625
# 2018-09-01 00:04:00            174.571365         158064.140625
#
#                      610FIC007 PID_PLA.SP  610FIC008 PID_PLA.SP  \
# DATE AND TIME
# 2018-09-01 00:00:00                   0.0                   0.0
# 2018-09-01 00:01:00                   0.0                   0.0
# 2018-09-01 00:02:00                   0.0                   0.0
# 2018-09-01 00:03:00                   0.0                   0.0
# 2018-09-01 00:04:00                   0.0                   0.0
#
#                      610FIC004 PID_PLA.SP  610FIC005S PID_PLA.SP  \
# DATE AND TIME
# 2018-09-01 00:00:00                   0.0                20000.0
# 2018-09-01 00:01:00                   0.0                20000.0
# 2018-09-01 00:02:00                   0.0                20000.0
# 2018-09-01 00:03:00                   0.0                20000.0
# 2018-09-01 00:04:00                   0.0                20000.0
#
#                      610FIC003 PID_PLA.SP  610FIC002 PID_PLA.SP  \
# DATE AND TIME
# 2018-09-01 00:00:00                6000.0                 700.0
# 2018-09-01 00:01:00                6000.0                 700.0
# 2018-09-01 00:02:00                6000.0                 700.0
# 2018-09-01 00:03:00                6000.0                 700.0
# 2018-09-01 00:04:00                6000.0                 700.0
#
#                      610PIC002 PID_PLA.SP
# DATE AND TIME
# 2018-09-01 00:00:00                   1.2
# 2018-09-01 00:01:00                   1.2
# 2018-09-01 00:02:00                   1.2
# 2018-09-01 00:03:00                   1.2
# 2018-09-01 00:04:00                   1.2
#
# [5 rows x 91 columns]

# %%
ends = []
for col_name,_ in data.iteritems():
    ends.append(col_name[-2:])
np.unique(ends, return_counts=True)
# Out:
# (array(['.1', 'A ', 'B ', 'OP', 'PV', 'SP'], dtype='<U2'),
#  array([  6,   1,   1, 101, 625,  91]))

# %%
plt.figure(figsize=(14,10))
i=np.random.randint(data.shape[1])
print(i)
print(data.columns[i])
plt.plot(data.index, data.iloc[:,i])
# Out:
# 314
# 610TI058FA PV

# %%
np.sum(data.iloc[:,155]>0)
# Out:
# 2384

# %%
rolling_means = data.rolling(20).mean()

# %%
plt.figure(figsize=(14,10))
i=np.random.randint(data.shape[1])
print(i)
print(data.columns[i])
plt.plot(data.index, data.iloc[:,i])
plt.plot(data.index, rolling_means.iloc[:,i], color='red')
# Out:
# 710
# 610PIC085 PID_PLA.PV

# %%
cumul_means = data.expanding().mean()

# %%
plt.figure(figsize=(14,10))
i=np.random.randint(data.shape[1])
print(i)
print(data.columns[i])
plt.plot(data.index, data.iloc[:,i])
plt.plot(data.index, cumul_means.iloc[:,i], color='red')
# Out:
# 596
# 610TIC182A PID_PLA.PV
